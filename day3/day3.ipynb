# %% [markdown]
# --- Day 3: Mull It Over ---
# "Our computers are having issues, so I have no idea if we have any Chief Historians in stock! You're welcome to check the warehouse, though," says the mildly flustered shopkeeper at the North Pole Toboggan Rental Shop. The Historians head out to take a look.
#
# The shopkeeper turns to you. "Any chance you can see why our computers are having issues again?"
#
# The computer appears to be trying to run a program, but its memory (your puzzle input) is corrupted. All of the instructions have been jumbled up!
#
# It seems like the goal of the program is just to multiply some numbers. It does that with instructions like mul(X,Y), where X and Y are each 1-3 digit numbers. For instance, mul(44,46) multiplies 44 by 46 to get a result of 2024. Similarly, mul(123,4) would multiply 123 by 4.
#
# However, because the program's memory has been corrupted, there are also many invalid characters that should be ignored, even if they look like part of a mul instruction. Sequences like mul(4*, mul(6,9!, ?(12,34), or mul ( 2 , 4 ) do nothing.
#
# For example, consider the following section of corrupted memory:
#
# xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))
# Only the four highlighted sections are real mul instructions. Adding up the result of each instruction produces 161 (24 + 55 + 118 + 85).
#
# Scan the corrupted memory for uncorrupted mul instructions. What do you get if you add up all of the results of the multiplications?

# %%
import re

def scan_memory_with_conditionals(text):
    """
    Scan corrupted memory text for valid mul instructions, respecting do() and don't() conditionals.
    
    Args:
        text (str): The corrupted memory text to scan
        
    Returns:
        int: Sum of all valid and enabled multiplication results
    """
    # Regular expressions for instructions
    mul_pattern = r'mul\((\d{1,3}),(\d{1,3})\)'
    do_pattern = r'do\(\)'
    dont_pattern = r'don\'t\(\)'
    
    # Get all instructions with their positions
    instructions = []
    
    # Find all mul instructions
    for match in re.finditer(mul_pattern, text):
        instructions.append({
            'type': 'mul',
            'pos': match.start(),
            'x': int(match.group(1)),
            'y': int(match.group(2))
        })
    
    # Find all do() instructions
    for match in re.finditer(do_pattern, text):
        instructions.append({
            'type': 'do',
            'pos': match.start()
        })
    
    # Find all don't() instructions
    for match in re.finditer(dont_pattern, text):
        instructions.append({
            'type': 'dont',
            'pos': match.start()
        })
    
    # Sort instructions by position
    instructions.sort(key=lambda x: x['pos'])
    
    # Process instructions
    total = 0
    enabled = True  # Initially enabled
    calculations = []
    
    for instruction in instructions:
        if instruction['type'] == 'do':
            enabled = True
        elif instruction['type'] == 'dont':
            enabled = False
        elif instruction['type'] == 'mul' and enabled:
            x = instruction['x']
            y = instruction['y']
            result = x * y
            calculations.append(f"{x} * {y} = {result} (enabled: {enabled})")
            total += result
        elif instruction['type'] == 'mul':
            x = instruction['x']
            y = instruction['y']
            calculations.append(f"{x} * {y} = {x * y} (enabled: {enabled}, not counted)")
    
    return total, calculations

def process_file(filename):
    """
    Read and process the input file.
    
    Args:
        filename (str): Path to the input file
        
    Returns:
        int: Sum of all enabled multiplication results
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
        total, calculations = scan_memory_with_conditionals(content)
        
        # Print each calculation for verification
        print("Individual calculations:")
        for calc in calculations:
            print(calc)
            
        print(f"\nTotal sum: {total}")
        return total
    except FileNotFoundError:
        print(f"Error: Could not find file {filename}")
        return None
    except Exception as e:
        print(f"Error processing file: {e}")
        return None

filename = r"input.txt" 

result = process_file(filename)

if result is not None:
    print(f"\nFinal answer: {result}")
# Out:
# Individual calculations:
# 747 * 16 = 11952 (enabled: True)
# 354 * 748 = 264792 (enabled: True)
# 29 * 805 = 23345 (enabled: True)
# 480 * 119 = 57120 (enabled: True)
# 685 * 393 = 269205 (enabled: True)
# 376 * 146 = 54896 (enabled: True)
# 735 * 916 = 673260 (enabled: True)
# 321 * 623 = 199983 (enabled: True)
# 363 * 643 = 233409 (enabled: True)
# 360 * 266 = 95760 (enabled: True)
# 95 * 167 = 15865 (enabled: True)
# 802 * 119 = 95438 (enabled: True)
# 147 * 169 = 24843 (enabled: True)
# 488 * 194 = 94672 (enabled: True)
# 540 * 154 = 83160 (enabled: True)
# 8 * 750 = 6000 (enabled: True)
# 140 * 841 = 117740 (enabled: True)
# 428 * 793 = 339404 (enabled: True)
# 156 * 996 = 155376 (enabled: True)
# 976 * 569 = 555344 (enabled: True)
# 426 * 703 = 299478 (enabled: True)
# 948 * 128 = 121344 (enabled: True)
# 477 * 567 = 270459 (enabled: True)
# 182 * 79 = 14378 (enabled: True)
# 203 * 707 = 143521 (enabled: True)
# 186 * 170 = 31620 (enabled: True)
# 130 * 392 = 50960 (enabled: True)
# 563 * 902 = 507826 (enabled: True)
# 953 * 129 = 122937 (enabled: True)
# 852 * 652 = 555504 (enabled: True)
# 973 * 163 = 158599 (enabled: True)
# 158 * 596 = 94168 (enabled: True)
# 968 * 252 = 243936 (enabled: True)
# 617 * 885 = 546045 (enabled: True)
# 264 * 456 = 120384 (enabled: True)
# 713 * 804 = 573252 (enabled: True)
# 803 * 862 = 692186 (enabled: True)
# 575 * 310 = 178250 (enabled: True)
# 475 * 876 = 416100 (enabled: True)
# 557 * 2 = 1114 (enabled: True)
# 611 * 157 = 95927 (enabled: True)
# 894 * 415 = 371010 (enabled: True)
# 856 * 397 = 339832 (enabled: True)
# 13 * 373 = 4849 (enabled: True)
# 395 * 375 = 148125 (enabled: True)
# 535 * 15 = 8025 (enabled: True)
# 115 * 296 = 34040 (enabled: True)
# 201 * 604 = 121404 (enabled: True)
# 34 * 586 = 19924 (enabled: True)
# 389 * 101 = 39289 (enabled: True)
# 501 * 691 = 346191 (enabled: False, not counted)
# 551 * 120 = 66120 (enabled: False, not counted)
# 492 * 926 = 455592 (enabled: False, not counted)
# 348 * 721 = 250908 (enabled: False, not counted)
# 811 * 483 = 391713 (enabled: False, not counted)
# 312 * 382 = 119184 (enabled: True)
# 224 * 412 = 92288 (enabled: True)
# 199 * 783 = 155817 (enabled: True)
# 267 * 247 = 65949 (enabled: True)
# 126 * 337 = 42462 (enabled: True)
# 534 * 156 = 83304 (enabled: True)
# 103 * 848 = 87344 (enabled: True)
# 237 * 35 = 8295 (enabled: True)
# 423 * 484 = 204732 (enabled: True)
# 281 * 866 = 243346 (enabled: True)
# 437 * 982 = 429134 (enabled: True)
# 357 * 682 = 243474 (enabled: True)
# 124 * 834 = 103416 (enabled: True)
# 668 * 671 = 448228 (enabled: True)
# 787 * 282 = 221934 (enabled: True)
# 669 * 479 = 320451 (enabled: True)
# 217 * 891 = 193347 (enabled: True)
# 157 * 768 = 120576 (enabled: True)
# 654 * 217 = 141918 (enabled: True)
# 173 * 829 = 143417 (enabled: True)
# 78 * 373 = 29094 (enabled: True)
# 985 * 702 = 691470 (enabled: True)
# 180 * 738 = 132840 (enabled: True)
# 240 * 76 = 18240 (enabled: True)
# 822 * 179 = 147138 (enabled: True)
# 682 * 60 = 40920 (enabled: False, not counted)
# 166 * 261 = 43326 (enabled: False, not counted)
# 602 * 939 = 565278 (enabled: False, not counted)
# 771 * 388 = 299148 (enabled: False, not counted)
# 646 * 938 = 605948 (enabled: False, not counted)
# 486 * 708 = 344088 (enabled: False, not counted)
# 144 * 833 = 119952 (enabled: False, not counted)
# 439 * 873 = 383247 (enabled: False, not counted)
# 25 * 577 = 14425 (enabled: False, not counted)
# 727 * 412 = 299524 (enabled: False, not counted)
# 826 * 116 = 95816 (enabled: False, not counted)
# 457 * 847 = 387079 (enabled: False, not counted)
# 145 * 20 = 2900 (enabled: False, not counted)
# 547 * 892 = 487924 (enabled: False, not counted)
# 835 * 616 = 514360 (enabled: False, not counted)
# 649 * 224 = 145376 (enabled: False, not counted)
# 35 * 958 = 33530 (enabled: False, not counted)
# 983 * 838 = 823754 (enabled: False, not counted)
# 614 * 657 = 403398 (enabled: False, not counted)
# 238 * 871 = 207298 (enabled: False, not counted)
# 943 * 599 = 564857 (enabled: False, not counted)
# 572 * 265 = 151580 (enabled: False, not counted)
# 454 * 326 = 148004 (enabled: False, not counted)
# 620 * 631 = 391220 (enabled: False, not counted)
# 300 * 416 = 124800 (enabled: False, not counted)
# 588 * 123 = 72324 (enabled: False, not counted)
# 757 * 105 = 79485 (enabled: False, not counted)
# 646 * 183 = 118218 (enabled: False, not counted)
# 208 * 472 = 98176 (enabled: False, not counted)
# 374 * 508 = 189992 (enabled: False, not counted)
# 936 * 836 = 782496 (enabled: False, not counted)
# 87 * 618 = 53766 (enabled: False, not counted)
# 549 * 158 = 86742 (enabled: False, not counted)
# 429 * 727 = 311883 (enabled: False, not counted)
# 883 * 372 = 328476 (enabled: False, not counted)
# 778 * 374 = 290972 (enabled: False, not counted)
# 156 * 180 = 28080 (enabled: False, not counted)
# 186 * 452 = 84072 (enabled: False, not counted)
# 801 * 495 = 396495 (enabled: False, not counted)
# 810 * 508 = 411480 (enabled: True)
# 101 * 25 = 2525 (enabled: True)
# 518 * 766 = 396788 (enabled: True)
# 276 * 326 = 89976 (enabled: True)
# 211 * 710 = 149810 (enabled: True)
# 414 * 532 = 220248 (enabled: True)
# 494 * 611 = 301834 (enabled: True)
# 90 * 974 = 87660 (enabled: True)
# 427 * 683 = 291641 (enabled: True)
# 443 * 135 = 59805 (enabled: True)
# 579 * 135 = 78165 (enabled: True)
# 267 * 452 = 120684 (enabled: True)
# 662 * 85 = 56270 (enabled: True)
# 724 * 771 = 558204 (enabled: True)
# 206 * 909 = 187254 (enabled: True)
# 260 * 632 = 164320 (enabled: True)
# 13 * 816 = 10608 (enabled: True)
# 351 * 795 = 279045 (enabled: True)
# 313 * 157 = 49141 (enabled: True)
# 222 * 186 = 41292 (enabled: True)
# 558 * 129 = 71982 (enabled: True)
# 927 * 606 = 561762 (enabled: True)
# 749 * 285 = 213465 (enabled: True)
# 919 * 804 = 738876 (enabled: True)
# 889 * 472 = 419608 (enabled: True)
# 597 * 828 = 494316 (enabled: True)
# 61 * 536 = 32696 (enabled: True)
# 50 * 308 = 15400 (enabled: True)
# 980 * 618 = 605640 (enabled: True)
# 506 * 77 = 38962 (enabled: True)
# 540 * 5 = 2700 (enabled: True)
# 128 * 695 = 88960 (enabled: True)
# 96 * 956 = 91776 (enabled: True)
# 45 * 167 = 7515 (enabled: True)
# 11 * 806 = 8866 (enabled: True)
# 226 * 600 = 135600 (enabled: True)
# 70 * 238 = 16660 (enabled: True)
# 447 * 978 = 437166 (enabled: True)
# 583 * 880 = 513040 (enabled: True)
# 509 * 562 = 286058 (enabled: True)
# 131 * 634 = 83054 (enabled: True)
# 212 * 467 = 99004 (enabled: True)
# 426 * 669 = 284994 (enabled: True)
# 722 * 873 = 630306 (enabled: True)
# 110 * 728 = 80080 (enabled: True)
# 948 * 566 = 536568 (enabled: True)
# 873 * 257 = 224361 (enabled: True)
# 210 * 425 = 89250 (enabled: False, not counted)
# 954 * 569 = 542826 (enabled: False, not counted)
# 514 * 751 = 386014 (enabled: False, not counted)
# 570 * 718 = 409260 (enabled: False, not counted)
# 369 * 56 = 20664 (enabled: False, not counted)
# 701 * 888 = 622488 (enabled: False, not counted)
# 954 * 415 = 395910 (enabled: False, not counted)
# 975 * 208 = 202800 (enabled: False, not counted)
# 123 * 114 = 14022 (enabled: False, not counted)
# 482 * 680 = 327760 (enabled: True)
# 455 * 447 = 203385 (enabled: True)
# 502 * 951 = 477402 (enabled: True)
# 953 * 617 = 588001 (enabled: True)
# 351 * 35 = 12285 (enabled: True)
# 450 * 397 = 178650 (enabled: True)
# 315 * 592 = 186480 (enabled: True)
# 361 * 911 = 328871 (enabled: True)
# 648 * 348 = 225504 (enabled: True)
# 741 * 895 = 663195 (enabled: True)
# 221 * 704 = 155584 (enabled: False, not counted)
# 869 * 570 = 495330 (enabled: False, not counted)
# 304 * 61 = 18544 (enabled: False, not counted)
# 380 * 797 = 302860 (enabled: False, not counted)
# 266 * 78 = 20748 (enabled: False, not counted)
# 336 * 100 = 33600 (enabled: False, not counted)
# 963 * 726 = 699138 (enabled: False, not counted)
# 738 * 99 = 73062 (enabled: False, not counted)
# 433 * 254 = 109982 (enabled: False, not counted)
# 612 * 425 = 260100 (enabled: False, not counted)
# 925 * 380 = 351500 (enabled: False, not counted)
# 590 * 924 = 545160 (enabled: False, not counted)
# 629 * 151 = 94979 (enabled: False, not counted)
# 231 * 925 = 213675 (enabled: False, not counted)
# 535 * 69 = 36915 (enabled: False, not counted)
# 695 * 901 = 626195 (enabled: False, not counted)
# 173 * 181 = 31313 (enabled: False, not counted)
# 478 * 661 = 315958 (enabled: False, not counted)
# 269 * 398 = 107062 (enabled: False, not counted)
# 203 * 769 = 156107 (enabled: False, not counted)
# 440 * 541 = 238040 (enabled: False, not counted)
# 264 * 622 = 164208 (enabled: False, not counted)
# 53 * 921 = 48813 (enabled: False, not counted)
# 802 * 877 = 703354 (enabled: False, not counted)
# 24 * 441 = 10584 (enabled: False, not counted)
# 83 * 37 = 3071 (enabled: False, not counted)
# 278 * 236 = 65608 (enabled: False, not counted)
# 486 * 676 = 328536 (enabled: False, not counted)
# 332 * 224 = 74368 (enabled: False, not counted)
# 786 * 79 = 62094 (enabled: False, not counted)
# 249 * 770 = 191730 (enabled: False, not counted)
# 617 * 783 = 483111 (enabled: False, not counted)
# 416 * 179 = 74464 (enabled: False, not counted)
# 148 * 463 = 68524 (enabled: False, not counted)
# 10 * 173 = 1730 (enabled: True)
# 613 * 997 = 611161 (enabled: True)
# 359 * 962 = 345358 (enabled: True)
# 276 * 357 = 98532 (enabled: True)
# 860 * 748 = 643280 (enabled: True)
# 407 * 102 = 41514 (enabled: False, not counted)
# 640 * 494 = 316160 (enabled: False, not counted)
# 724 * 407 = 294668 (enabled: True)
# 472 * 652 = 307744 (enabled: False, not counted)
# 350 * 214 = 74900 (enabled: False, not counted)
# 108 * 897 = 96876 (enabled: False, not counted)
# 177 * 623 = 110271 (enabled: False, not counted)
# 674 * 586 = 394964 (enabled: False, not counted)
# 188 * 601 = 112988 (enabled: False, not counted)
# 892 * 181 = 161452 (enabled: False, not counted)
# 904 * 15 = 13560 (enabled: False, not counted)
# 832 * 651 = 541632 (enabled: False, not counted)
# 485 * 621 = 301185 (enabled: False, not counted)
# 964 * 655 = 631420 (enabled: False, not counted)
# 950 * 896 = 851200 (enabled: False, not counted)
# 103 * 475 = 48925 (enabled: False, not counted)
# 165 * 476 = 78540 (enabled: False, not counted)
# 417 * 206 = 85902 (enabled: False, not counted)
# 162 * 447 = 72414 (enabled: False, not counted)
# 794 * 412 = 327128 (enabled: False, not counted)
# 419 * 168 = 70392 (enabled: False, not counted)
# 689 * 382 = 263198 (enabled: False, not counted)
# 868 * 352 = 305536 (enabled: False, not counted)
# 245 * 790 = 193550 (enabled: False, not counted)
# 334 * 775 = 258850 (enabled: False, not counted)
# 874 * 152 = 132848 (enabled: False, not counted)
# 771 * 202 = 155742 (enabled: False, not counted)
# 331 * 997 = 330007 (enabled: False, not counted)
# 230 * 638 = 146740 (enabled: False, not counted)
# 729 * 194 = 141426 (enabled: False, not counted)
# 669 * 652 = 436188 (enabled: False, not counted)
# 799 * 156 = 124644 (enabled: False, not counted)
# 666 * 169 = 112554 (enabled: False, not counted)
# 381 * 557 = 212217 (enabled: False, not counted)
# 534 * 338 = 180492 (enabled: False, not counted)
# 631 * 275 = 173525 (enabled: False, not counted)
# 847 * 310 = 262570 (enabled: False, not counted)
# 321 * 129 = 41409 (enabled: False, not counted)
# 888 * 479 = 425352 (enabled: False, not counted)
# 229 * 502 = 114958 (enabled: False, not counted)
# 246 * 553 = 136038 (enabled: False, not counted)
# 242 * 385 = 93170 (enabled: False, not counted)
# 445 * 61 = 27145 (enabled: False, not counted)
# 521 * 245 = 127645 (enabled: False, not counted)
# 784 * 56 = 43904 (enabled: False, not counted)
# 373 * 342 = 127566 (enabled: False, not counted)
# 513 * 340 = 174420 (enabled: False, not counted)
# 967 * 981 = 948627 (enabled: False, not counted)
# 244 * 532 = 129808 (enabled: False, not counted)
# 686 * 40 = 27440 (enabled: False, not counted)
# 178 * 177 = 31506 (enabled: False, not counted)
# 595 * 777 = 462315 (enabled: False, not counted)
# 210 * 328 = 68880 (enabled: False, not counted)
# 252 * 597 = 150444 (enabled: False, not counted)
# 940 * 426 = 400440 (enabled: False, not counted)
# 71 * 619 = 43949 (enabled: False, not counted)
# 811 * 55 = 44605 (enabled: False, not counted)
# 442 * 618 = 273156 (enabled: False, not counted)
# 71 * 211 = 14981 (enabled: False, not counted)
# 146 * 583 = 85118 (enabled: False, not counted)
# 453 * 186 = 84258 (enabled: False, not counted)
# 667 * 596 = 397532 (enabled: False, not counted)
# 387 * 262 = 101394 (enabled: False, not counted)
# 720 * 489 = 352080 (enabled: False, not counted)
# 715 * 93 = 66495 (enabled: False, not counted)
# 440 * 43 = 18920 (enabled: False, not counted)
# 546 * 613 = 334698 (enabled: False, not counted)
# 69 * 463 = 31947 (enabled: False, not counted)
# 255 * 367 = 93585 (enabled: False, not counted)
# 654 * 641 = 419214 (enabled: False, not counted)
# 620 * 43 = 26660 (enabled: False, not counted)
# 573 * 638 = 365574 (enabled: False, not counted)
# 450 * 634 = 285300 (enabled: False, not counted)
# 142 * 868 = 123256 (enabled: False, not counted)
# 723 * 185 = 133755 (enabled: False, not counted)
# 305 * 502 = 153110 (enabled: False, not counted)
# 621 * 328 = 203688 (enabled: False, not counted)
# 179 * 100 = 17900 (enabled: False, not counted)
# 94 * 187 = 17578 (enabled: False, not counted)
# 509 * 291 = 148119 (enabled: False, not counted)
# 379 * 538 = 203902 (enabled: True)
# 830 * 641 = 532030 (enabled: True)
# 180 * 491 = 88380 (enabled: True)
# 266 * 732 = 194712 (enabled: True)
# 575 * 752 = 432400 (enabled: True)
# 850 * 918 = 780300 (enabled: True)
# 782 * 495 = 387090 (enabled: True)
# 957 * 190 = 181830 (enabled: True)
# 352 * 79 = 27808 (enabled: True)
# 652 * 626 = 408152 (enabled: True)
# 973 * 815 = 792995 (enabled: True)
# 327 * 736 = 240672 (enabled: True)
# 221 * 196 = 43316 (enabled: True)
# 170 * 288 = 48960 (enabled: True)
# 65 * 844 = 54860 (enabled: False, not counted)
# 152 * 544 = 82688 (enabled: False, not counted)
# 847 * 27 = 22869 (enabled: False, not counted)
# 736 * 195 = 143520 (enabled: False, not counted)
# 663 * 417 = 276471 (enabled: False, not counted)
# 301 * 538 = 161938 (enabled: False, not counted)
# 271 * 885 = 239835 (enabled: False, not counted)
# 251 * 286 = 71786 (enabled: False, not counted)
# 664 * 742 = 492688 (enabled: False, not counted)
# 583 * 557 = 324731 (enabled: False, not counted)
# 636 * 736 = 468096 (enabled: False, not counted)
# 733 * 889 = 651637 (enabled: False, not counted)
# 415 * 907 = 376405 (enabled: False, not counted)
# 746 * 170 = 126820 (enabled: False, not counted)
# 520 * 584 = 303680 (enabled: False, not counted)
# 423 * 117 = 49491 (enabled: False, not counted)
# 100 * 371 = 37100 (enabled: False, not counted)
# 434 * 31 = 13454 (enabled: False, not counted)
# 142 * 115 = 16330 (enabled: False, not counted)
# 863 * 234 = 201942 (enabled: False, not counted)
# 722 * 893 = 644746 (enabled: False, not counted)
# 101 * 716 = 72316 (enabled: False, not counted)
# 881 * 570 = 502170 (enabled: False, not counted)
# 315 * 278 = 87570 (enabled: False, not counted)
# 237 * 596 = 141252 (enabled: False, not counted)
# 565 * 260 = 146900 (enabled: False, not counted)
# 4 * 427 = 1708 (enabled: False, not counted)
# 361 * 206 = 74366 (enabled: False, not counted)
# 575 * 211 = 121325 (enabled: False, not counted)
# 996 * 776 = 772896 (enabled: False, not counted)
# 803 * 47 = 37741 (enabled: False, not counted)
# 239 * 900 = 215100 (enabled: False, not counted)
# 129 * 262 = 33798 (enabled: False, not counted)
# 433 * 265 = 114745 (enabled: False, not counted)
# 653 * 369 = 240957 (enabled: False, not counted)
# 299 * 195 = 58305 (enabled: False, not counted)
# 885 * 839 = 742515 (enabled: False, not counted)
# 335 * 155 = 51925 (enabled: False, not counted)
# 775 * 440 = 341000 (enabled: False, not counted)
# 599 * 234 = 140166 (enabled: False, not counted)
# 339 * 978 = 331542 (enabled: True)
# 404 * 428 = 172912 (enabled: True)
# 148 * 78 = 11544 (enabled: True)
# 862 * 926 = 798212 (enabled: True)
# 189 * 238 = 44982 (enabled: True)
# 481 * 269 = 129389 (enabled: True)
# 97 * 894 = 86718 (enabled: True)
# 164 * 658 = 107912 (enabled: True)
# 459 * 615 = 282285 (enabled: True)
# 632 * 943 = 595976 (enabled: True)
# 364 * 748 = 272272 (enabled: True)
# 214 * 990 = 211860 (enabled: True)
# 206 * 633 = 130398 (enabled: True)
# 14 * 141 = 1974 (enabled: True)
# 822 * 373 = 306606 (enabled: True)
# 688 * 489 = 336432 (enabled: True)
# 305 * 206 = 62830 (enabled: True)
# 304 * 632 = 192128 (enabled: False, not counted)
# 291 * 282 = 82062 (enabled: False, not counted)
# 662 * 53 = 35086 (enabled: False, not counted)
# 5 * 779 = 3895 (enabled: False, not counted)
# 111 * 303 = 33633 (enabled: False, not counted)
# 852 * 693 = 590436 (enabled: False, not counted)
# 249 * 548 = 136452 (enabled: False, not counted)
# 387 * 459 = 177633 (enabled: False, not counted)
# 112 * 988 = 110656 (enabled: False, not counted)
# 191 * 655 = 125105 (enabled: False, not counted)
# 79 * 498 = 39342 (enabled: False, not counted)
# 513 * 202 = 103626 (enabled: False, not counted)
# 224 * 73 = 16352 (enabled: False, not counted)
# 737 * 275 = 202675 (enabled: False, not counted)
# 739 * 419 = 309641 (enabled: False, not counted)
# 842 * 699 = 588558 (enabled: False, not counted)
# 816 * 564 = 460224 (enabled: False, not counted)
# 66 * 866 = 57156 (enabled: False, not counted)
# 846 * 687 = 581202 (enabled: False, not counted)
# 268 * 28 = 7504 (enabled: False, not counted)
# 398 * 631 = 251138 (enabled: False, not counted)
# 283 * 82 = 23206 (enabled: False, not counted)
# 837 * 666 = 557442 (enabled: False, not counted)
# 31 * 972 = 30132 (enabled: False, not counted)
# 850 * 483 = 410550 (enabled: False, not counted)
# 58 * 370 = 21460 (enabled: False, not counted)
# 363 * 410 = 148830 (enabled: False, not counted)
# 617 * 613 = 378221 (enabled: False, not counted)
# 876 * 980 = 858480 (enabled: False, not counted)
# 749 * 501 = 375249 (enabled: False, not counted)
# 720 * 734 = 528480 (enabled: False, not counted)
# 380 * 889 = 337820 (enabled: False, not counted)
# 48 * 988 = 47424 (enabled: False, not counted)
# 968 * 247 = 239096 (enabled: False, not counted)
# 884 * 462 = 408408 (enabled: False, not counted)
# 177 * 831 = 147087 (enabled: False, not counted)
# 4 * 455 = 1820 (enabled: False, not counted)
# 729 * 440 = 320760 (enabled: False, not counted)
# 688 * 376 = 258688 (enabled: False, not counted)
# 211 * 599 = 126389 (enabled: False, not counted)
# 192 * 204 = 39168 (enabled: False, not counted)
# 133 * 244 = 32452 (enabled: False, not counted)
# 729 * 105 = 76545 (enabled: False, not counted)
# 900 * 829 = 746100 (enabled: False, not counted)
# 83 * 600 = 49800 (enabled: False, not counted)
# 434 * 610 = 264740 (enabled: False, not counted)
# 691 * 992 = 685472 (enabled: False, not counted)
# 892 * 279 = 248868 (enabled: False, not counted)
# 720 * 864 = 622080 (enabled: False, not counted)
# 303 * 491 = 148773 (enabled: False, not counted)
# 720 * 732 = 527040 (enabled: False, not counted)
# 407 * 549 = 223443 (enabled: False, not counted)
# 127 * 272 = 34544 (enabled: False, not counted)
# 322 * 71 = 22862 (enabled: False, not counted)
# 650 * 186 = 120900 (enabled: False, not counted)
# 887 * 229 = 203123 (enabled: False, not counted)
# 753 * 118 = 88854 (enabled: False, not counted)
# 683 * 687 = 469221 (enabled: False, not counted)
# 471 * 355 = 167205 (enabled: False, not counted)
# 271 * 372 = 100812 (enabled: False, not counted)
# 68 * 707 = 48076 (enabled: False, not counted)
# 811 * 52 = 42172 (enabled: False, not counted)
# 160 * 946 = 151360 (enabled: False, not counted)
# 206 * 444 = 91464 (enabled: False, not counted)
# 299 * 200 = 59800 (enabled: False, not counted)
# 298 * 431 = 128438 (enabled: False, not counted)
# 822 * 566 = 465252 (enabled: False, not counted)
# 401 * 194 = 77794 (enabled: False, not counted)
# 320 * 99 = 31680 (enabled: False, not counted)
# 635 * 430 = 273050 (enabled: False, not counted)
# 474 * 531 = 251694 (enabled: False, not counted)
# 915 * 913 = 835395 (enabled: False, not counted)
# 896 * 524 = 469504 (enabled: False, not counted)
# 245 * 843 = 206535 (enabled: False, not counted)
# 707 * 597 = 422079 (enabled: False, not counted)
# 864 * 931 = 804384 (enabled: False, not counted)
# 605 * 621 = 375705 (enabled: False, not counted)
# 700 * 646 = 452200 (enabled: False, not counted)
# 297 * 15 = 4455 (enabled: False, not counted)
# 87 * 793 = 68991 (enabled: False, not counted)
# 518 * 305 = 157990 (enabled: False, not counted)
# 588 * 968 = 569184 (enabled: False, not counted)
# 295 * 237 = 69915 (enabled: False, not counted)
# 590 * 124 = 73160 (enabled: False, not counted)
# 719 * 423 = 304137 (enabled: False, not counted)
# 902 * 901 = 812702 (enabled: False, not counted)
# 455 * 460 = 209300 (enabled: False, not counted)
# 24 * 765 = 18360 (enabled: False, not counted)
# 19 * 771 = 14649 (enabled: False, not counted)
# 380 * 138 = 52440 (enabled: False, not counted)
# 333 * 659 = 219447 (enabled: False, not counted)
# 310 * 90 = 27900 (enabled: False, not counted)
# 494 * 223 = 110162 (enabled: False, not counted)
# 656 * 481 = 315536 (enabled: False, not counted)
# 985 * 195 = 192075 (enabled: False, not counted)
# 156 * 227 = 35412 (enabled: False, not counted)
# 475 * 974 = 462650 (enabled: False, not counted)
# 981 * 216 = 211896 (enabled: False, not counted)
# 243 * 273 = 66339 (enabled: False, not counted)
# 510 * 175 = 89250 (enabled: False, not counted)
# 705 * 700 = 493500 (enabled: False, not counted)
# 7 * 569 = 3983 (enabled: False, not counted)
# 324 * 975 = 315900 (enabled: False, not counted)
# 883 * 226 = 199558 (enabled: True)
# 660 * 990 = 653400 (enabled: True)
# 426 * 750 = 319500 (enabled: True)
# 790 * 641 = 506390 (enabled: True)
# 751 * 795 = 597045 (enabled: True)
# 633 * 76 = 48108 (enabled: True)
# 320 * 249 = 79680 (enabled: False, not counted)
# 51 * 601 = 30651 (enabled: False, not counted)
# 611 * 916 = 559676 (enabled: False, not counted)
# 174 * 972 = 169128 (enabled: False, not counted)
# 108 * 242 = 26136 (enabled: True)
# 870 * 660 = 574200 (enabled: True)
# 635 * 416 = 264160 (enabled: True)
# 236 * 788 = 185968 (enabled: True)
# 104 * 324 = 33696 (enabled: True)
# 81 * 926 = 75006 (enabled: True)
# 77 * 726 = 55902 (enabled: True)
# 56 * 385 = 21560 (enabled: True)
# 497 * 356 = 176932 (enabled: True)
# 870 * 813 = 707310 (enabled: True)
# 537 * 196 = 105252 (enabled: True)
# 584 * 253 = 147752 (enabled: True)
# 788 * 391 = 308108 (enabled: True)
# 157 * 737 = 115709 (enabled: False, not counted)
# 908 * 38 = 34504 (enabled: False, not counted)
# 773 * 541 = 418193 (enabled: False, not counted)
# 97 * 620 = 60140 (enabled: False, not counted)
# 899 * 189 = 169911 (enabled: False, not counted)
# 566 * 974 = 551284 (enabled: False, not counted)
# 908 * 528 = 479424 (enabled: False, not counted)
# 71 * 100 = 7100 (enabled: False, not counted)
# 628 * 153 = 96084 (enabled: False, not counted)
# 765 * 691 = 528615 (enabled: False, not counted)
# 186 * 21 = 3906 (enabled: False, not counted)
# 487 * 725 = 353075 (enabled: False, not counted)
# 110 * 152 = 16720 (enabled: True)
# 992 * 213 = 211296 (enabled: True)
# 797 * 726 = 578622 (enabled: True)
# 969 * 578 = 560082 (enabled: True)
# 440 * 56 = 24640 (enabled: True)
# 113 * 81 = 9153 (enabled: True)
# 277 * 301 = 83377 (enabled: True)
# 121 * 117 = 14157 (enabled: True)
# 15 * 795 = 11925 (enabled: True)
# 575 * 181 = 104075 (enabled: True)
# 178 * 328 = 58384 (enabled: True)
# 801 * 216 = 173016 (enabled: True)
# 431 * 843 = 363333 (enabled: True)
# 147 * 629 = 92463 (enabled: True)
# 993 * 659 = 654387 (enabled: True)
# 518 * 738 = 382284 (enabled: True)
# 160 * 896 = 143360 (enabled: True)
# 173 * 649 = 112277 (enabled: True)
# 463 * 794 = 367622 (enabled: True)
# 480 * 942 = 452160 (enabled: True)
# 731 * 892 = 652052 (enabled: True)
# 948 * 47 = 44556 (enabled: True)
# 219 * 441 = 96579 (enabled: True)
# 383 * 202 = 77366 (enabled: True)
# 679 * 266 = 180614 (enabled: True)
# 206 * 774 = 159444 (enabled: True)
# 996 * 344 = 342624 (enabled: True)
# 332 * 248 = 82336 (enabled: True)
# 114 * 169 = 19266 (enabled: True)
# 692 * 942 = 651864 (enabled: True)
# 120 * 876 = 105120 (enabled: True)
# 761 * 409 = 311249 (enabled: True)
# 518 * 173 = 89614 (enabled: True)
# 405 * 527 = 213435 (enabled: True)
# 950 * 134 = 127300 (enabled: True)
# 814 * 585 = 476190 (enabled: True)
# 816 * 366 = 298656 (enabled: True)
# 105 * 532 = 55860 (enabled: True)
# 151 * 891 = 134541 (enabled: True)
# 178 * 962 = 171236 (enabled: True)
# 751 * 447 = 335697 (enabled: True)
# 851 * 764 = 650164 (enabled: True)
# 588 * 654 = 384552 (enabled: True)
# 882 * 76 = 67032 (enabled: True)
# 526 * 650 = 341900 (enabled: True)
# 29 * 13 = 377 (enabled: True)
# 56 * 722 = 40432 (enabled: True)
# 946 * 420 = 397320 (enabled: True)
# 718 * 516 = 370488 (enabled: True)
# 400 * 748 = 299200 (enabled: True)
# 357 * 947 = 338079 (enabled: True)
# 430 * 803 = 345290 (enabled: True)
# 445 * 455 = 202475 (enabled: True)
# 490 * 913 = 447370 (enabled: True)
# 646 * 393 = 253878 (enabled: True)
# 901 * 342 = 308142 (enabled: True)
# 499 * 634 = 316366 (enabled: True)
# 996 * 710 = 707160 (enabled: True)
# 8 * 949 = 7592 (enabled: True)
# 860 * 166 = 142760 (enabled: True)
# 739 * 160 = 118240 (enabled: True)
# 988 * 26 = 25688 (enabled: True)
# 293 * 416 = 121888 (enabled: True)
# 215 * 463 = 99545 (enabled: True)
# 152 * 776 = 117952 (enabled: True)
# 447 * 726 = 324522 (enabled: True)
# 182 * 115 = 20930 (enabled: True)
# 335 * 275 = 92125 (enabled: True)
# 704 * 863 = 607552 (enabled: True)
# 709 * 745 = 528205 (enabled: True)
# 17 * 822 = 13974 (enabled: True)
# 280 * 107 = 29960 (enabled: True)
# 288 * 599 = 172512 (enabled: True)
# 463 * 772 = 357436 (enabled: True)
# 992 * 279 = 276768 (enabled: True)
# 348 * 687 = 239076 (enabled: True)
# 477 * 896 = 427392 (enabled: True)
# 804 * 970 = 779880 (enabled: True)
# 166 * 890 = 147740 (enabled: True)
# 892 * 532 = 474544 (enabled: True)
# 905 * 17 = 15385 (enabled: True)
# 361 * 902 = 325622 (enabled: True)
# 924 * 910 = 840840 (enabled: True)
# 322 * 152 = 48944 (enabled: True)
# 503 * 282 = 141846 (enabled: True)
# 678 * 160 = 108480 (enabled: True)
# 661 * 59 = 38999 (enabled: True)
# 572 * 448 = 256256 (enabled: True)
# 509 * 887 = 451483 (enabled: True)
# 393 * 953 = 374529 (enabled: True)
# 546 * 677 = 369642 (enabled: False, not counted)
# 657 * 456 = 299592 (enabled: False, not counted)
# 527 * 553 = 291431 (enabled: False, not counted)
# 639 * 12 = 7668 (enabled: False, not counted)
# 437 * 929 = 405973 (enabled: False, not counted)
# 298 * 239 = 71222 (enabled: False, not counted)
# 727 * 688 = 500176 (enabled: True)
# 720 * 201 = 144720 (enabled: True)
# 139 * 406 = 56434 (enabled: True)
# 123 * 17 = 2091 (enabled: True)
# 407 * 428 = 174196 (enabled: True)
# 606 * 64 = 38784 (enabled: True)
# 652 * 400 = 260800 (enabled: True)
# 850 * 192 = 163200 (enabled: True)
# 184 * 269 = 49496 (enabled: True)
# 655 * 422 = 276410 (enabled: True)
# 905 * 342 = 309510 (enabled: True)
# 185 * 967 = 178895 (enabled: True)
# 594 * 891 = 529254 (enabled: True)
# 641 * 786 = 503826 (enabled: True)
# 185 * 960 = 177600 (enabled: False, not counted)
# 702 * 204 = 143208 (enabled: False, not counted)
# 24 * 904 = 21696 (enabled: False, not counted)
# 109 * 193 = 21037 (enabled: False, not counted)
# 579 * 493 = 285447 (enabled: False, not counted)
# 473 * 16 = 7568 (enabled: False, not counted)
# 33 * 997 = 32901 (enabled: False, not counted)
# 104 * 325 = 33800 (enabled: False, not counted)
# 486 * 457 = 222102 (enabled: False, not counted)
# 720 * 711 = 511920 (enabled: False, not counted)
# 239 * 525 = 125475 (enabled: True)
# 77 * 963 = 74151 (enabled: True)
# 856 * 16 = 13696 (enabled: True)
# 356 * 792 = 281952 (enabled: True)
# 15 * 617 = 9255 (enabled: True)
# 878 * 763 = 669914 (enabled: True)
# 427 * 938 = 400526 (enabled: True)
# 208 * 838 = 174304 (enabled: True)
# 982 * 594 = 583308 (enabled: True)
# 683 * 977 = 667291 (enabled: True)
# 541 * 415 = 224515 (enabled: True)
# 648 * 533 = 345384 (enabled: True)
# 291 * 292 = 84972 (enabled: True)
# 65 * 4 = 260 (enabled: True)
# 466 * 215 = 100190 (enabled: True)
# 637 * 530 = 337610 (enabled: True)
# 75 * 335 = 25125 (enabled: True)
# 738 * 984 = 726192 (enabled: True)
# 916 * 756 = 692496 (enabled: True)
# 991 * 341 = 337931 (enabled: True)
# 145 * 20 = 2900 (enabled: True)
# 279 * 825 = 230175 (enabled: True)
# 326 * 199 = 64874 (enabled: True)
# 112 * 738 = 82656 (enabled: True)
# 887 * 573 = 508251 (enabled: True)
# 795 * 440 = 349800 (enabled: True)
# 94 * 274 = 25756 (enabled: True)
# 841 * 178 = 149698 (enabled: True)
# 127 * 186 = 23622 (enabled: True)
# 291 * 547 = 159177 (enabled: True)
# 21 * 379 = 7959 (enabled: True)
# 172 * 574 = 98728 (enabled: True)
# 765 * 254 = 194310 (enabled: True)
# 448 * 944 = 422912 (enabled: True)
# 452 * 303 = 136956 (enabled: True)
# 55 * 517 = 28435 (enabled: True)
# 949 * 308 = 292292 (enabled: True)
# 185 * 245 = 45325 (enabled: True)
# 89 * 379 = 33731 (enabled: True)
#
# Total sum: 77055967
#
# Final answer: 77055967

# %% [markdown]
# --- Part Two ---
# As you scan through the corrupted memory, you notice that some of the conditional statements are also still intact. If you handle some of the uncorrupted conditional statements in the program, you might be able to get an even more accurate result.
#
# There are two new instructions you'll need to handle:
#
# The do() instruction enables future mul instructions.
# The don't() instruction disables future mul instructions.
# Only the most recent do() or don't() instruction applies. At the beginning of the program, mul instructions are enabled.
#
# For example:
#
# xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))
# This corrupted memory is similar to the example from before, but this time the mul(5,5) and mul(11,8) instructions are disabled because there is a don't() instruction before them. The other mul instructions function normally, including the one at the end that gets re-enabled by a do() instruction.
#
# This time, the sum of the results is 48 (24 + 85).
#
# Handle the new instructions; what do you get if you add up all of the results of just the enabled multiplications?

# %%
import re

# Open and read the input file
with open('input.txt', 'r') as file:
    data = file.read()

# Regular expressions to match instructions
mul_pattern = r"mul\((\d{1,3}),(\d{1,3})\)"  # Matches mul(X,Y)
do_pattern = r"do\(\)"                        # Matches do()
dont_pattern = r"don't\(\)"                   # Matches don't()

# Find all matches in the input, preserving order
instructions = re.findall(f"({do_pattern})|({dont_pattern})|{mul_pattern}", data)

# Variable to track if mul instructions are enabled
enabled = True

# Variable to store the total sum
total = 0

# Process each instruction
for instruction in instructions:
    if instruction[0]:  # Matches do()
        enabled = True
    elif instruction[1]:  # Matches don't()
        enabled = False
    elif instruction[2] and instruction[3] and enabled:  # Matches mul(X,Y) if enabled
        x, y = map(int, instruction[2:4])  # Extract numbers from the mul() match
        total += x * y  # Add their product to the total

# Print the result
print(total)
# Out:
# 77055967
